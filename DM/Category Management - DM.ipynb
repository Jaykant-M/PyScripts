# %%
print("Hello")
# Out:
# Hello

# %%
#RUN "pip install openpyxl" in order to start using excel files

# %%
import numpy as np
import pandas as pd
#import matplotlib.pyplot as plt
import openpyxl
import os

# %%
sheet = pd.ExcelFile(r'C:\Users\Jay\Desktop\Python learning\Raw.xlsx')
print(sheet.sheet_names) #this returns the all the sheets in the excel file
# Out:
# ['Products Information', 'Sales History', 'Miscellaneous']

# %%
PI = sheet.parse(sheet_name='Products Information')
SH = sheet.parse(sheet_name='Sales History')
MI = sheet.parse(sheet_name='Miscellaneous')

# %%
type(PI)
# Out:
# pandas.core.frame.DataFrame

# %%
PI
# Out:
#                Category         UPC         Product Description    Size UOM  \
# 0     Laundry Dtergents  2420008955                DUTCH DRY PP  32.000  OZ
# 1               Cereals  3800000535        KELLOGGS RICE KRISPI  19.000  OZ
# 2               Cereals  3800001011          KELLOGGS CORN POPS  15.000  OZ
# 3               Cereals  3800003700        KELLOGS RAISIN SQUAR  16.000  OZ
# 4               Cereals  3800013900        KELLOGGS RICE KRISPI  14.800  OZ
# 5   Refrigirated Juices  2500002606  MIN MAID O J REGULAR 64 OZ  64.000  OZ
# 6   Refrigirated Juices  2500002623  MIN MAID O J PLASTIC 96 OZ  96.000  OZ
# 7   Refrigirated Juices  2500002645  MIN MAID FRUIT PUNCH 64 OZ  64.000  OZ
# 8               Shampoo  8087802546  PANTENE PRO-V NORMAL 13 OZ  13.000  OZ
# 9               Cereals  3000002580        QUAKER TOASTED OATME  16.000  OZ
# 10              Cereals  3000006430          QUAKER OAT SQUARES  16.000  OZ
# 11              Cereals  3000006500         QUAKER P.B. CAPTAIN  15.000  OZ
# 12              Cereals  1600065700        CINNAMON TOAST CRUNC  14.000  OZ
# 13              Cereals  1600065720        CINNAMON TOAST CRUNC  20.000  OZ
# 14              Cereals  1600065850           WHOLE GRAIN TOTAL  12.000  OZ
# 15              Cereals  1600066310                         KIX   9.000  OZ
# 16    Laundry Dtergents  7506400090        RPC LIQUID LAUNDRY D  64.000  OZ
# 17              Shampoo  3007466061          SW BLUE X/MED 7 OZ   7.000  OZ
# 18  Refrigirated Juices  8390001301           SW ICED TEA 64 OZ  64.000  OZ
# 19              Shampoo  7940074070  SUAVE MOISTURIZING S 15 OZ  15.000  OZ
# 20              Shampoo  7940074090  SUAVE X/B MOIST COND 15 OZ  15.000  OZ
# 21              Shampoo  7940077250  SUAVE SHAM + COND N/ 11 OZ  11.000  OZ
# 22  Refrigirated Juices  4850000102      TROP PURE PRM OJ 64 OZ  64.000  OZ
# 23  Refrigirated Juices  4850000139  TROP PURE PRM HOMEST 64 OZ  64.000  OZ
# 24  Refrigirated Juices  4850000250      TROP PURE PRM OJ 96 OZ  96.000  OZ
# 25  Refrigirated Juices  4850000274    TROP PURE PRM OJ 0,375OZ   0.375  OZ
# 26  Refrigirated Juices  4850000414  TROP OJ PREM GROVEST 64 OZ  64.000  OZ
# 27    Laundry Dtergents  6233806130              WOOLITE LIQUID  16.000  OZ
# 28    Laundry Dtergents  6233806160              WOOLITE LIQUID  32.000  OZ
#
#           BRAND
# 0     DUTCH DRY
# 1       KELLOGS
# 2       KELLOGS
# 3       KELLOGS
# 4       KELLOGS
# 5   MINUTE MAID
# 6   MINUTE MAID
# 7   MINUTE MAID
# 8       PANTENE
# 9        QUAKER
# 10       QUAKER
# 11       QUAKER
# 12  CROSSBORDER
# 13  CROSSBORDER
# 14  CROSSBORDER
# 15  CROSSBORDER
# 16  CROSSBORDER
# 17  CROSSBORDER
# 18  CROSSBORDER
# 19        SUAVE
# 20        SUAVE
# 21        SUAVE
# 22    TROPICANA
# 23    TROPICANA
# 24    TROPICANA
# 25    TROPICANA
# 26    TROPICANA
# 27      WOOLITE
# 28      WOOLITE

# %%
SH.head(5)
# Out:
#    Year  Store  Quarter            Category         UPC  \
# 0     1      1        1  Laundry Detergents  6233806160
# 1     1      5        1             Shampoo  7940074090
# 2     1      4        1             Shampoo  7940077250
# 3     1      5        1             Shampoo  7940077250
# 4     1      4        1             Shampoo  7940074090
#
#                  Product Desc  Week  ForPrice  ActualPrice  Cost  \
# 0              WOOLITE LIQUID   201      5.19         2.75  3.04
# 1  SUAVE X/B MOIST COND 15 OZ   201      0.99         0.99  1.04
# 2  SUAVE SHAM + COND N/ 11 OZ   201      0.99         0.99  1.03
# 3  SUAVE SHAM + COND N/ 11 OZ   201      0.99         0.99  1.03
# 4  SUAVE X/B MOIST COND 15 OZ   201      0.99         0.99  1.04
#
#    Actual Sales  ForSales  Act Revenue  For Revenue
# 0             5         7        13.75        36.33
# 1             3         3         2.97         2.97
# 2             3         3         2.97         2.97
# 3             3         3         2.97         2.97
# 4             2         2         1.98         1.98

# %%
SH.keys()
# Out:
# Index(['Year', 'Store', 'Quarter', 'Category', 'UPC', 'Product Desc', 'Week',
#        'ForPrice', 'ActualPrice', 'Cost', 'Actual Sales', 'ForSales',
#        'Act Revenue', 'For Revenue'],
#       dtype='object')

# %%
SH.columns = ['Year', 'Store', 'Quarter', 'Category', 'UPC', 'Product Desc', 'Week',
              'Forcasted Price', 'Actual Price', 'Cost', 'Actual Sales', 'Forcasted Sales',
              'Actual Revenue', 'Forcasted Revenue']

# %%
#SH.keys()

# %%
Des = SH["Product Desc"].unique()
print('number of unique items - ', len(Des))
# Out:
# number of unique items -  28

# %%
UPC = SH["UPC"].unique()
print('number of unique items -', (len(UPC)))
# Out:
# number of unique items - 29

# %%
PI["Product Description"].duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28     True
# Name: Product Description, dtype: bool

# %%
l = PI["Product Description"]
l1 = []
dup = []
for i in l:
    if i not in l1:
        l1.append(i)
    else:
        dup.append(i)

# %%
dup
# Out:
# ['KELLOGGS RICE KRISPI', 'CINNAMON TOAST CRUNC', 'WOOLITE LIQUID']

# %%
dup_UPC = []
dup_Prod = []
dup_Size = []
for i in PI.index:
    if PI.loc[i,"Product Description"] in dup:
        print(PI.loc[i,"UPC"] , PI.loc[i,"Product Description"])
        dup_UPC.append(PI.loc[i,"UPC"])
        dup_Prod.append(PI.loc[i,"Product Description"])  
        dup_Size.append(PI.loc[i,"Size"])
# Out:
# 3800000535 KELLOGGS RICE KRISPI
# 3800013900 KELLOGGS RICE KRISPI
# 1600065700 CINNAMON TOAST CRUNC
# 1600065720 CINNAMON TOAST CRUNC
# 6233806130 WOOLITE LIQUID
# 6233806160 WOOLITE LIQUID

# %%
dup_UPC
# Out:
# [3800000535, 3800013900, 1600065700, 1600065720, 6233806130, 6233806160]

# %%
dup_Prod
# Out:
# ['KELLOGGS RICE KRISPI',
#  'KELLOGGS RICE KRISPI',
#  'CINNAMON TOAST CRUNC',
#  'CINNAMON TOAST CRUNC',
#  'WOOLITE LIQUID',
#  'WOOLITE LIQUID']

# %%
dup_Size
# Out:
# [19.0, 14.8, 14.0, 20.0, 16.0, 32.0]

# %%
Dup_Rec_series = {
    "UPC" : [3800000535, 3800013900, 1600065700, 1600065720, 6233806130, 6233806160],
    "Prod": ['KELLOGGS RICE KRISPI 19 OZ',
 'KELLOGGS RICE KRISPI 14.8 OZ',
 'CINNAMON TOAST CRUNC 14 OZ',
 'CINNAMON TOAST CRUNC 20 OZ',
 'WOOLITE LIQUID 16 OZ',
 'WOOLITE LIQUID 32 OZ'],
    "Size": [19.0, 14.8, 14.0, 20.0, 16.0, 32.0]
}

# %%
DS = pd.DataFrame(Dup_Rec_series)

# %%
DS
# Out:
#           UPC                          Prod  Size
# 0  3800000535    KELLOGGS RICE KRISPI 19 OZ  19.0
# 1  3800013900  KELLOGGS RICE KRISPI 14.8 OZ  14.8
# 2  1600065700    CINNAMON TOAST CRUNC 14 OZ  14.0
# 3  1600065720    CINNAMON TOAST CRUNC 20 OZ  20.0
# 4  6233806130          WOOLITE LIQUID 16 OZ  16.0
# 5  6233806160          WOOLITE LIQUID 32 OZ  32.0

# %%
type(DS)
# Out:
# pandas.core.frame.DataFrame

# %%
for x in SH.index:
    for y in DS.index:
        if SH.loc[x,"UPC"] == DS.loc[y,"UPC"]:
            #print(SH.loc[x,"Product Desc"] , DS.loc[y,"Prod"] , DS.loc[y,"UPC"])
            SH.loc[x,"Product Desc"] = DS.loc[y,"Prod"]
            #SH.loc[x,"Product Desc"] = DS.loc[y,"Prod"]

# %%
for y in PI.index:
    for z in DS.index:
        if PI.loc[y,"UPC"] == DS.loc[z,"UPC"]:
            #print(SH.loc[x,"Product Desc"] , DS.loc[y,"Prod"] , DS.loc[y,"UPC"])
            PI.loc[y,"Product Description"] = DS.loc[z,"Prod"]

# %%
#PI = PI.drop(columns = "Product Desccription")

# %%
PI
# Out:
#                Category         UPC           Product Description    Size UOM  \
# 0     Laundry Dtergents  2420008955                  DUTCH DRY PP  32.000  OZ
# 1               Cereals  3800000535    KELLOGGS RICE KRISPI 19 OZ  19.000  OZ
# 2               Cereals  3800001011            KELLOGGS CORN POPS  15.000  OZ
# 3               Cereals  3800003700          KELLOGS RAISIN SQUAR  16.000  OZ
# 4               Cereals  3800013900  KELLOGGS RICE KRISPI 14.8 OZ  14.800  OZ
# 5   Refrigirated Juices  2500002606    MIN MAID O J REGULAR 64 OZ  64.000  OZ
# 6   Refrigirated Juices  2500002623    MIN MAID O J PLASTIC 96 OZ  96.000  OZ
# 7   Refrigirated Juices  2500002645    MIN MAID FRUIT PUNCH 64 OZ  64.000  OZ
# 8               Shampoo  8087802546    PANTENE PRO-V NORMAL 13 OZ  13.000  OZ
# 9               Cereals  3000002580          QUAKER TOASTED OATME  16.000  OZ
# 10              Cereals  3000006430            QUAKER OAT SQUARES  16.000  OZ
# 11              Cereals  3000006500           QUAKER P.B. CAPTAIN  15.000  OZ
# 12              Cereals  1600065700    CINNAMON TOAST CRUNC 14 OZ  14.000  OZ
# 13              Cereals  1600065720    CINNAMON TOAST CRUNC 20 OZ  20.000  OZ
# 14              Cereals  1600065850             WHOLE GRAIN TOTAL  12.000  OZ
# 15              Cereals  1600066310                           KIX   9.000  OZ
# 16    Laundry Dtergents  7506400090          RPC LIQUID LAUNDRY D  64.000  OZ
# 17              Shampoo  3007466061            SW BLUE X/MED 7 OZ   7.000  OZ
# 18  Refrigirated Juices  8390001301             SW ICED TEA 64 OZ  64.000  OZ
# 19              Shampoo  7940074070    SUAVE MOISTURIZING S 15 OZ  15.000  OZ
# 20              Shampoo  7940074090    SUAVE X/B MOIST COND 15 OZ  15.000  OZ
# 21              Shampoo  7940077250    SUAVE SHAM + COND N/ 11 OZ  11.000  OZ
# 22  Refrigirated Juices  4850000102        TROP PURE PRM OJ 64 OZ  64.000  OZ
# 23  Refrigirated Juices  4850000139    TROP PURE PRM HOMEST 64 OZ  64.000  OZ
# 24  Refrigirated Juices  4850000250        TROP PURE PRM OJ 96 OZ  96.000  OZ
# 25  Refrigirated Juices  4850000274      TROP PURE PRM OJ 0,375OZ   0.375  OZ
# 26  Refrigirated Juices  4850000414    TROP OJ PREM GROVEST 64 OZ  64.000  OZ
# 27    Laundry Dtergents  6233806130          WOOLITE LIQUID 16 OZ  16.000  OZ
# 28    Laundry Dtergents  6233806160          WOOLITE LIQUID 32 OZ  32.000  OZ
#
#           BRAND
# 0     DUTCH DRY
# 1       KELLOGS
# 2       KELLOGS
# 3       KELLOGS
# 4       KELLOGS
# 5   MINUTE MAID
# 6   MINUTE MAID
# 7   MINUTE MAID
# 8       PANTENE
# 9        QUAKER
# 10       QUAKER
# 11       QUAKER
# 12  CROSSBORDER
# 13  CROSSBORDER
# 14  CROSSBORDER
# 15  CROSSBORDER
# 16  CROSSBORDER
# 17  CROSSBORDER
# 18  CROSSBORDER
# 19        SUAVE
# 20        SUAVE
# 21        SUAVE
# 22    TROPICANA
# 23    TROPICANA
# 24    TROPICANA
# 25    TROPICANA
# 26    TROPICANA
# 27      WOOLITE
# 28      WOOLITE

# %%
'''
for x in SH.index:
    if SH.loc[x,"UPC"] in [3800000535, 3800013900, 1600065700, 1600065720, 6233806130, 6233806160]:
        print(SH.loc[x,"Product Desc"])
'''
# Out:
# '\nfor x in SH.index:\n    if SH.loc[x,"UPC"] in [3800000535, 3800013900, 1600065700, 1600065720, 6233806130, 6233806160]:\n        print(SH.loc[x,"Product Desc"])\n'

# %% [markdown]
# Data cleaning done
#
# 1) Refrigerated spelling mistake corrected
#
# 2) Duplicate product name in Product information table been fixed.
#
# 3) Detergent spelling issue corrected.
#
# 4) Product Desc in Sales History been updated - referenced to Product information Table.
